# %% [markdown]
# <a href="https://colab.research.google.com/github/jpfula91ut/portafolio/blob/main/U7Sesion_4_Ejercicio_1030683444.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SEMANA 4
# 1 EJERCICIO

# %%
import pandas as pd
asig = ["Matematica", "Fisica", "Quimica", "Historia", "Lengua", "Programacion"]
nota =[]

for i in asig:
  nota.append(float(input(f"ingrese nota de su materia: {i}: ")))
for z in range(len(asig)):
  print(f"Materia: {asig[z]} nota: {nota[z]}")

# %% [markdown]
# 2 EJERCICIO

# %%
cesta ={}
cant = 0
while True:
    producto = input("Ingrese el producto, si desea finalizar compra escriba FIN ")
    if producto.upper() == "FIN":
        print(f"Total de compra: {cant}")
        break
    precio_producto = float(input(f"Ingrese el precio del producto :"))
    cant += precio_producto
    for key, values in cesta.items():
        precio_total += precio_producto
        print(f"producto: {key}, precio: {values}")

# %% [markdown]
# 4 EJERCICIO

# %%
empleados = []

print(" 1_añadir empleado \n 2_retirar empleado \n 3_base de empleados \n 4_salir")

cursor = int(input("Ingrese opcion: "))

if cursor == 1:
  empleados = input("Nombre Empleado: ")
elif cursor == 2:
  drop_emple = input("Nombre Empleado: ")
  if drop_emple in empleados:
    empleados.remove(drop_emple)
    print("se retira empleado de manera correcta")
  else:
    print("No registra empleado")
elif cursor == 3:
  print(empleados)
elif cursor == 4:
  print ("Fin de Operación")
else:
  print("Opcion incorrecta")

# %% [markdown]
#  3 EJERCICIO

# %% [markdown]
# 5 EJERCICIO

# %%
from ast import Break
from contextlib import nullcontext
import numpy as np
import pandas as pd

notas= {'estudiantes':[],'nota':[]}
notas['estudiantes'].append(input("Ingrese al estudian6te que desea integrar notas: "))
cant_notas = int(input("Ingrese la catidad de notas a integrar del estudiante: "))

for i in range(cant_notas):
    notas['nota'] = input("Ingrese la nota del estudiante: ")
    for z in cant_notas:
      cant_notas -= 1
      if cant_notas == 0:
        break
print(notas)
# Out:
# Ingrese al estudian6te que desea integrar notas: tt
# Ingrese la catidad de notas a integrar del estudiante: 2
# Ingrese la nota del estudiante: 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3081263196.py in <cell line: 0>()
#      10 for i in range(cant_notas):
#      11     notas['nota'] = input("Ingrese la nota del estudiante: ")
# ---> 12     for z in cant_notas:
#      13       cant_notas -= 1
#      14       if cant_notas == 0:
#
# TypeError: 'int' object is not iterable
