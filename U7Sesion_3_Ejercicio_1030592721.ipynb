# %% [markdown]
# <a href="https://colab.research.google.com/github/jpfula91ut/portafolio/blob/main/U7Sesion_3_Ejercicio_1030592721.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1: Media: Realizar un programa que solicite al usuario 3 números e imprima la media de estos

# %%
a = float(input("brindar segundo numero: "))
b = float(input("brindar segundo numero: "))
c = float(input("brindar tercer numero: "))

promedio = (a+b+c)/3
print("el promedio es", promedio)
# Out:
# brindar segundo numero: 0

# %% [markdown]
# Ejercicio 2:  Escribir un programa que pida al usuario su peso(en kg) y estatura (en metros), calcule el índice de masa corporal(IMC) y muestre en pantalla la frase: Tu índice de masa corporal es: <imc> , donde imc es el calculo realizado. Este imc debe estar redondeado con dos decimales

# %%
peso = float(input("Ingresa tu peso en kilogramos"))
altura = float(input("Ingresa tu estatura en metros"))

if peso <= 0 or altura <= 0:
  print("Error: El peso y la estatura deben ser valores positivos.")
else:

  imc = peso / altura**2
  imc_redondeado = round(imc, 2)

  print("Tu índice de masa corporal (imc) es:", imc)
# Out:
# Ingresa tu peso en kilogramos0
# Ingresa tu estatura en metros1.80
# Error: El peso y la estatura deben ser valores positivos.

# %% [markdown]
# Ejercicio 3. Escribir un programa que pregunte al usuario por el número de horas trabajadas y el costo por hora. Después muestre en pantalla el pago que le corresponde

# %%
horas_trabajadas = float(input("Ingresa el número de horas trabajadas: "))
costo_por_hora = float(input("ingresa el costo por hora: "))

pago = horas_trabajadas * costo_por_hora

if costo_por_hora <= 0 or horas_trabajadas <= 0:
  print("Error: El costo por hora y el número de horas trabajadas deben ser valores positivos.")
else:
  print(f"tu pago por las horas trabajadas son: {pago} pesos colombianos(COP)")
# Out:
# Ingresa el número de horas trabajadas: 10
# ingresa el costo por hora: -3000
# Error: El costo por hora y el número de horas trabajadas deben ser valores positivos.

# %% [markdown]
# Ejercicio 4.Se necesita elaborar un algoritmo en Python que solicite al usuario el número de respuestas correctas, incorrectas y en blanco correspondiente a los postulantes y muestre su puntaje final considerando que por cada respuesta correcta, tendrá 3 puntos, respuestas incorrectas tendrá -1 y respuestas en blanco será 0 (cero)

# %%
r_correcta = int(input("ingrese el numero de respuestas correctas: "))
r_incorrecta = int(input("ingrese el numero de respuestas incorrectas: "))
r_en_blanco = int(input("ingrese el numero de respuestas en blanco: "))

if r_correcta < 0 or r_incorrecta < 0 or r_en_blanco < 0:
  print("Error: El número de respuestas no puede ser negativo.")

puntaje_total = (r_correcta * 3) + (r_incorrecta * -1) + (r_en_blanco * 0)

print(f"su puntaje total corresponde {puntaje_total}")
# Out:
# ingrese el numero de respuestas correctas: 10
# ingrese el numero de respuestas incorrectas: 0
# ingrese el numero de respuestas en blanco: 3
# su puntaje total corresponde 30

# %% [markdown]
# Ejercicio 5. Hacer un programa que solicite al usuario números enteros siempre y cuando sean menores de 10 e imprima la multiplicación de cada uno de los números digitados(3*5*6*3..). Cuando el usuario digite un número mayor de 10 imprima la multiplicación que lleva hasta el momento

# %%
multiplicacion = 1

while True:
  numero = int(input("Ingrese número entero:"))
  if numero >= 10:
    print(f"Multiplicación hasta el momento es: {multiplicacion}")
    break
  multiplicacion *= numero
# Out:
# Ingrese número entero:3
# Ingrese número entero:5
# Ingrese número entero:10
# Multiplicación hasta el momento es: 15
